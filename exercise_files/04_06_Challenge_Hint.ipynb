# %% [markdown]
# ## ASCII Art Encoding

# %% [markdown]
# ### Challenge Hints!

# %% [markdown]
# **Hint 1:** While iterating through each character of a string, we can print out when a string has "switched" from one character to another:

# %%
stringVal = 'AAAAABBBBBCCCCC'

prevChar = None
for char in stringVal:
    if char != prevChar:
        print(f'New character is {char}')
    prevChar = char
# Out:
# New character is A
# New character is B
# New character is C

# %% [markdown]
# **Hint 2:** Remember that you can multiply a string by a number!

# %%
'A'*5
# Out:
# 'AAAAA'

# %%
def encodeString(stringVal):
    pass

def decodeString(encodedList):
    pass

# %%
art = '''

                                                                                
                                                                                
                               %%%%%%%%%%%%%%%%%%%                              
                        %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%                       
                    %%%%%%%%                         %%%%%%%%                   
                %%%%%%%                                   %%%%%%                
              %%%%%%                                         %%%%%%             
           %%%%%%                                               %%%%%           
          %%%%%                                                   %%%%%         
        %%%%%                                                       %%%%%       
       %%%%                 %%%%%              %%%%%                  %%%%      
      %%%%                 %%%%%%%            %%%%%%%                  %%%%     
     %%%%                  %%%%%%%            %%%%%%%                   %%%%    
    %%%%                   %%%%%%%            %%%%%%%                    %%%%   
    %%%%                    %%%%%              %%%%%                     %%%%   
   %%%%                                                                   %%%%  
   %%%%                                                                   %%%%  
   %%%%                                                                   %%%%  
   %%%%                                                      %%%%        %%%%   
    %%%%       %%%%%%                                        %%%%%       %%%%   
    %%%%         %%%%                                       %%%%        %%%%    
     %%%%         %%%%                                     %%%%         %%%%    
      %%%%         %%%%%                                  %%%%         %%%%     
       %%%%%         %%%%%                             %%%%%         %%%%%      
        %%%%%          %%%%%%                        %%%%%          %%%%        
          %%%%%           %%%%%%%               %%%%%%%           %%%%%         
            %%%%%             %%%%%%%%%%%%%%%%%%%%%             %%%%%           
              %%%%%%%                                        %%%%%              
                 %%%%%%%                                 %%%%%%%                
                     %%%%%%%%%                     %%%%%%%%%                    
                          %%%%%%%%%%%%%%%%%%%%%%%%%%%%%                         
                                   %%%%%%%%%%%%                                 
                                                                                
                                                                                 

'''

# %%
encodedString = encodeString(art)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 encodedString = encodeString(art)
#
# NameError: name 'encodeString' is not defined

# %%
decodeString(encodedString)

# %%
stringVal = 'AAAAABBBBBCCCCC'
encodedList = [('A', 5), ('B', 5), ('C', 5)]
decodedString = 'AAAAABBBBBCCCCC'
assert(encodeString(stringVal) == encodedList)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[6], line 4
#       2 encodedList = [('A', 5), ('B', 5), ('C', 5)]
#       3 decodedString = 'AAAAABBBBBCCCCC'
# ----> 4 assert(encodeString(stringVal) == encodedList)
#
# AssertionError:
