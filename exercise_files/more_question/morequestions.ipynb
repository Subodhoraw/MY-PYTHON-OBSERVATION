# %%
# %pip install fpdf
import fpdf
from fpdf import FPDF

# --- All 200+ Questions (organized by tiers) ---
questions = {
    "Tier 1 — Beginner (0–1 year)": [
        "Explain Python’s execution model for a simple script.",
        "List Python’s core built-in data types and give a one-line example for each.",
        "Explain the difference between == and is with a short example.",
        "Why are Python strings immutable? Give two practical consequences.",
        "Compare list, tuple, set, and dict in terms of mutability and typical use case.",
        "Show two ways to iterate over a list with indexes.",
        "What is Python’s indentation rule and why is it critical?",
        "Explain Python’s garbage collection mechanism in simple terms.",
        "What does PEP 8 refer to, and why is it important?",
        "What are Python’s reserved keywords? Give 5 examples.",
        # ... continue until 50
    ],
    "Tier 2 — Junior (1–2 years)": [
        "Explain the difference between a module and a package.",
        "How does Python import system resolve modules?",
        "Explain __init__.py and its purpose.",
        "What is __name__ == '__main__' used for?",
        "Describe Python’s exception hierarchy. Why subclass Exception instead of BaseException?",
        "Explain try/except/else/finally with an example.",
        "What is logging in Python? Show a basic setup.",
        "Explain shallow copy vs deep copy with code.",
        "What is virtualenv/venv and why is it important?",
        "Explain pip and dependency management best practices.",
        # ... continue until 100
    ],
    "Tier 3 — Mid-Level (2–5 years)": [
        "Explain Python’s Global Interpreter Lock (GIL).",
        "How do you achieve true parallelism in Python?",
        "Compare threading vs multiprocessing vs asyncio.",
        "What are Python coroutines? Show a short async/await example.",
        "Explain how decorators work internally. Write your own.",
        "What are context managers? Implement a custom one with __enter__ and __exit__.",
        "Explain generators vs iterators.",
        "How does yield differ from return?",
        "What are Python descriptors? Give an example.",
        "Explain the difference between slots and __dict__ in classes.",
        # ... continue until 150
    ],
    "Tier 4 — Senior (5+ years)": [
        "Explain memory profiling in Python. How do you reduce memory usage in large data pipelines?",
        "What is monkey patching? Give pros and cons.",
        "How do you design a plugin architecture in Python?",
        "Explain metaclasses. When would you use them?",
        "How does Python’s importlib work?",
        "What are abstract base classes (ABC)? Why use them?",
        "Explain dependency injection in Python. Show a simple frameworkless example.",
        "What is the difference between duck typing and structural typing?",
        "Explain Python’s typing system (mypy, type hints).",
        "What is Cython and when would you use it?",
        # ... continue until 200
    ]
}

# --- PDF Generator ---
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", 'B', 16)
pdf.cell(200, 10, "Python Mastery: 200+ Questions & Coding Workbook", ln=True, align="C")
pdf.ln(10)

for tier, qs in questions.items():
    pdf.set_font("Arial", 'B', 14)
    pdf.cell(200, 10, tier, ln=True)
    pdf.ln(5)
    pdf.set_font("Arial", size=11)
    for i, q in enumerate(qs, 1):
        pdf.multi_cell(0, 8, f"{i}. {q}")
        pdf.ln(5)  # extra space for writing answers

pdf.output("python_mastery_200_questions.pdf")
print("✅ PDF generated: python_mastery_200_questions.pdf")
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[4], line 77
#      74         pdf.multi_cell(0, 8, f"{i}. {q}")
#      75         pdf.ln(5)  # extra space for writing answers
# ---> 77 pdf.output("python_mastery_200_questions.pdf")
#      78 print("✅ PDF generated: python_mastery_200_questions.pdf")
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\fpdf\fpdf.py:1065, in FPDF.output(self, name, dest)
#    1063 #Finish document if necessary
#    1064 if(self.state<3):
# -> 1065     self.close()
#    1066 dest=dest.upper()
#    1067 if(dest==''):
#
# ...

# %%
from fpdf import FPDF

# --- All 200+ Questions (organized by tiers) ---
questions = {
    "Tier 1 — Beginner (0–1 year)": [
        "Explain Python’s execution model for a simple script.",
        "List Python’s core built-in data types and give a one-line example for each.",
        "Explain the difference between == and is with a short example.",
        "Why are Python strings immutable? Give two practical consequences.",
        "Compare list, tuple, set, and dict in terms of mutability and typical use case.",
        "Show two ways to iterate over a list with indexes.",
        "What is Python’s indentation rule and why is it critical?",
        "Explain Python’s garbage collection mechanism in simple terms.",
        "What does PEP 8 refer to, and why is it important?",
        "What are Python’s reserved keywords? Give 5 examples.",
        # ... continue until 50
    ],
    "Tier 2 — Junior (1–2 years)": [
        "Explain the difference between a module and a package.",
        "How does Python import system resolve modules?",
        "Explain __init__.py and its purpose.",
        "What is __name__ == '__main__' used for?",
        "Describe Python’s exception hierarchy. Why subclass Exception instead of BaseException?",
        "Explain try/except/else/finally with an example.",
        "What is logging in Python? Show a basic setup.",
        "Explain shallow copy vs deep copy with code.",
        "What is virtualenv/venv and why is it important?",
        "Explain pip and dependency management best practices.",
        # ... continue until 100
    ],
    "Tier 3 — Mid-Level (2–5 years)": [
        "Explain Python’s Global Interpreter Lock (GIL).",
        "How do you achieve true parallelism in Python?",
        "Compare threading vs multiprocessing vs asyncio.",
        "What are Python coroutines? Show a short async/await example.",
        "Explain how decorators work internally. Write your own.",
        "What are context managers? Implement a custom one with __enter__ and __exit__.",
        "Explain generators vs iterators.",
        "How does yield differ from return?",
        "What are Python descriptors? Give an example.",
        "Explain the difference between slots and __dict__ in classes.",
        # ... continue until 150
    ],
    "Tier 4 — Senior (5+ years)": [
        "Explain memory profiling in Python. How do you reduce memory usage in large data pipelines?",
        "What is monkey patching? Give pros and cons.",
        "How do you design a plugin architecture in Python?",
        "Explain metaclasses. When would you use them?",
        "How does Python’s importlib work?",
        "What are abstract base classes (ABC)? Why use them?",
        "Explain dependency injection in Python. Show a simple frameworkless example.",
        "What is the difference between duck typing and structural typing?",
        "Explain Python’s typing system (mypy, type hints).",
        "What is Cython and when would you use it?",
        # ... continue until 200
    ]
}

# --- PDF Generator ---
pdf = FPDF()
pdf.add_page()
pdf.set_font("Arial", 'B', 16)
pdf.cell(200, 10, "Python Mastery: 200+ Questions & Coding Workbook", ln=True, align="C")
pdf.ln(10)

for tier, qs in questions.items():
    pdf.set_font("Arial", 'B', 14)
    pdf.cell(200, 10, tier, ln=True)
    pdf.ln(5)
    pdf.set_font("Arial", size=11)
    for i, q in enumerate(qs, 1):
        pdf.multi_cell(0, 8, f"{i}. {q}")
        pdf.ln(5)  # extra space for writing answers

pdf.output("python_mastery_200_questions.pdf")
print("✅ PDF generated: python_mastery_200_questions.pdf")
# Out:
# ---------------------------------------------------------------------------
# UnicodeEncodeError                        Traceback (most recent call last)
# Cell In[5], line 75
#      72         pdf.multi_cell(0, 8, f"{i}. {q}")
#      73         pdf.ln(5)  # extra space for writing answers
# ---> 75 pdf.output("python_mastery_200_questions.pdf")
#      76 print("✅ PDF generated: python_mastery_200_questions.pdf")
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\fpdf\fpdf.py:1065, in FPDF.output(self, name, dest)
#    1063 #Finish document if necessary
#    1064 if(self.state<3):
# -> 1065     self.close()
#    1066 dest=dest.upper()
#    1067 if(dest==''):
#
# File c:\Users\Lenovo\AppData\Local\Programs\Python\Python313\Lib\site-packages\fpdf\fpdf.py:246, in FPDF.close(self)
#     244 self._endpage()
#     245 #close document
# --> 246 self._enddoc()
#
# ...
